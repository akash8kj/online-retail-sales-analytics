# %%
import pandas as pd

# %%
df = pd.read_excel(r"File_Location")

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.isnull().mean()*100
# Out:
# InvoiceNo       0.000000
# StockCode       0.000000
# Description     0.268311
# Quantity        0.000000
# InvoiceDate     0.000000
# UnitPrice       0.000000
# CustomerID     24.926694
# Country         0.000000
# dtype: float64

# %%
df[df['UnitPrice'] < 0].head(10)
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df[df['UnitPrice'] < 0].shape
# Out:
# (2, 8)

# %%
### Negative Unit Prices

Two records contain negative `UnitPrice` values. Both are described as `Adjust bad debt` and have no `CustomerID`, indicating that they are accounting adjustments rather than normal product transactions.

These records will be excluded from the cleaned sales dataset because the project focuses on retail sales transactions.

# %%
df = df[df['UnitPrice'] >= 0].copy()

# %%
df.shape
# Out:
# (541907, 8)

# %%
df[df['Quantity'] < 0].head(10)
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 141   C536379         D                           Discount        -1
# 154   C536383    35004C    SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
# 939   C536506     22960           JAM MAKING SET WITH JARS        -6
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# ...

# %%
df[df['Quantity'] < 0]['InvoiceNo'].astype(str).str.startswith('C').value_counts()
# Out:
# InvoiceNo
# True     9288
# False    1336
# Name: count, dtype: int64

# %%
df[df['Quantity'] < 0].shape
# Out:
# (10624, 8)

# %%
df[df['Quantity'] < 0]['InvoiceNo'].astype(str).str.startswith('C').value_counts()
# Out:
# InvoiceNo
# True     9288
# False    1336
# Name: count, dtype: int64

# %%
df[(df['Quantity'] < 0) & (~df['InvoiceNo'].astype(str).str.startswith('C'))].head(20)
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 2406    536589     21777         NaN       -10 2010-12-01 16:50:00        0.0
# 4347    536764    84952C         NaN       -38 2010-12-02 14:42:00        0.0
# 7188    536996     22712         NaN       -20 2010-12-03 15:30:00        0.0
# 7189    536997     22028         NaN       -20 2010-12-03 15:30:00        0.0
# 7190    536998     85067         NaN        -6 2010-12-03 15:30:00        0.0
# 7192    537000     21414         NaN       -22 2010-12-03 15:32:00        0.0
# 7193    537001     21653         NaN        -6 2010-12-03 15:33:00        0.0
# 7195    537003     85126         NaN        -2 2010-12-03 15:33:00        0.0
# 7196    537004     21814         NaN       -30 2010-12-03 15:34:00        0.0
# 7197    537005     21692         NaN       -70 2010-12-03 15:35:00        0.0
# 7198    537006     21648         NaN      -130 2010-12-03 15:36:00        0.0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
df = df.drop_duplicates().copy()

# %%
df.shape
# Out:
# (536639, 8)

# %%
df = df.dropna(subset=['CustomerID']).copy()

# %%
df = df.dropna(subset=['Description']).copy()

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (401604, 8)

# %%
df.to_excel("online_retail_cleaned.xlsx", index=False)
